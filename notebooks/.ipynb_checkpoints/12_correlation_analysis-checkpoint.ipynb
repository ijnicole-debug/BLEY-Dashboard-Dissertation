# %% [markdown]
# ## Correlation Analysis

# %%
#load needed libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
df = pd.read_csv('../data_clean/master_dataset.csv')

# %%
#correlation analysis
corr = df.drop(columns=['la_code', 'borough', 'average_house_price']).corr()
corr
# Out:
#                           gld       fsm       sen     idaci    ofsted  \
# gld                  1.000000 -0.395175 -0.078935 -0.394981 -0.041829
# fsm                 -0.395175  1.000000  0.667018  0.803097  0.113950
# sen                 -0.078935  0.667018  1.000000  0.595406  0.093794
# idaci               -0.394981  0.803097  0.595406  1.000000 -0.226128
# ofsted              -0.041829  0.113950  0.093794 -0.226128  1.000000
# inspection_coverage  0.023242 -0.035587 -0.138137  0.097874 -0.252177
# total_places         0.370186 -0.238825  0.082342 -0.098309 -0.204447
# under5               0.032968 -0.130127 -0.207862  0.139041 -0.523094
# childcare_per_100    0.446040 -0.144638  0.245139 -0.335378  0.385014
# ethnic_diversity    -0.295407  0.483722  0.220845  0.475205 -0.206121
#
#                      inspection_coverage  total_places    under5  \
# gld                             0.023242      0.370186  0.032968
# fsm                            -0.035587     -0.238825 -0.130127
# sen                            -0.138137      0.082342 -0.207862
# idaci                           0.097874     -0.098309  0.139041
# ofsted                         -0.252177     -0.204447 -0.523094
# inspection_coverage             1.000000     -0.320939  0.221416
# total_places                   -0.320939      1.000000  0.630756
# under5                          0.221416      0.630756  1.000000
# childcare_per_100              -0.632957      0.340041 -0.486693
# ethnic_diversity                0.435763     -0.233032  0.306495
#
#                      childcare_per_100  ethnic_diversity
# gld                           0.446040         -0.295407
# fsm                          -0.144638          0.483722
# sen                           0.245139          0.220845
# idaci                        -0.335378          0.475205
# ofsted                        0.385014         -0.206121
# inspection_coverage          -0.632957          0.435763
# total_places                  0.340041         -0.233032
# under5                       -0.486693          0.306495
# childcare_per_100             1.000000         -0.631375
# ethnic_diversity             -0.631375          1.000000

# %%
#plot correlation matrix
plt.figure(figsize=(10,8))

sns.heatmap (corr, annot=True, cmap='RdYlGn', center=0, fmt='.2f')

plt.title('Correlation Matrix')
plt.show()
