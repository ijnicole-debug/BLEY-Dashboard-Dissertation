# %% [markdown]
# ## Correlation Analysis

# %%
#load needed libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
df = pd.read_csv('../data_clean/master_dataset.csv')

# %%
#correlation analysis
corr = df.drop(columns=['la_code', 'borough']).corr()
corr
# Out:
#                           gld       fsm       sen     idaci    ofsted  \
# gld                  1.000000 -0.395175 -0.078935 -0.394981  0.046716
# fsm                 -0.395175  1.000000  0.667018  0.803097 -0.087501
# sen                 -0.078935  0.667018  1.000000  0.595406 -0.157285
# idaci               -0.394981  0.803097  0.595406  1.000000  0.184753
# ofsted               0.046716 -0.087501 -0.157285  0.184753  1.000000
# total_places         0.370186 -0.238825  0.082342 -0.098309 -0.133048
# under5               0.032968 -0.130127 -0.207862  0.139041  0.433163
# childcare_per_100    0.446040 -0.144638  0.245139 -0.335378 -0.665803
# ethnic_diversity    -0.295407  0.483722  0.220845  0.475205  0.427714
# average_house_price  0.004555  0.289003  0.204006 -0.184399 -0.531205
#
#                      total_places    under5  childcare_per_100  \
# gld                      0.370186  0.032968           0.446040
# fsm                     -0.238825 -0.130127          -0.144638
# sen                      0.082342 -0.207862           0.245139
# idaci                   -0.098309  0.139041          -0.335378
# ofsted                  -0.133048  0.433163          -0.665803
# total_places             1.000000  0.630756           0.340041
# under5                   0.630756  1.000000          -0.486693
# childcare_per_100        0.340041 -0.486693           1.000000
# ethnic_diversity        -0.233032  0.306495          -0.631375
# average_house_price     -0.415047 -0.673375           0.358834
#
#                      ethnic_diversity  average_house_price
# gld                         -0.295407             0.004555
# fsm                          0.483722             0.289003
# sen                          0.220845             0.204006
# idaci                        0.475205            -0.184399
# ofsted                       0.427714            -0.531205
# total_places                -0.233032            -0.415047
# under5                       0.306495            -0.673375
# childcare_per_100           -0.631375             0.358834
# ethnic_diversity             1.000000             0.059415
# average_house_price          0.059415             1.000000

# %%
#plot correlation matrix
plt.figure(figsize=(10,8))

sns.heatmap (corr, annot=True, cmap='RdYlGn', center=0, fmt='.2f')

plt.title('Correlation Matrix')
plt.show()

# %%
#without City of London
df = df[df['borough'] != 'City of London']
