# %% [markdown]
# ## DATA CLEANING- CHILDCARE PLACES PER 100 UNDER 5s

# %%
#import libraries
import pandas as pd

# Load dataset
df = pd.read_csv('../data_clean/ons_under5.csv')
df_places = pd.read_csv('../data_clean/ofsted_places.csv')

# %%
#quick preview
print(df.head())
# Out:
#                   borough  under5  total_pop
# 0                  Camden    9934     220903
# 1          City of London     215      13462
# 2                 Hackney   16247     263282
# 3  Hammersmith and Fulham    9237     186176
# 4                Haringey   14962     262895

# %%
#quick preview
print(df_places.head())
# Out:
#                 borough  total_places
# 0  Barking and Dagenham          3361
# 1                Barnet          7451
# 2                Bexley          5029
# 3                 Brent          4779
# 4               Bromley          8144

# %%
#merge data
df = pd.merge(df, df_places, on='borough', how='inner')

# %%
#calculate childcare access
df['childcare_per_100'] = (df['total_places'] / df['under5'] * 100)

# %%
#final structure
df_clean = df[['borough', 'childcare_per_100']]
df_clean = df_clean.sort_values(by='borough').reset_index(drop=True)

# %%
#validate
print("Rows:", len(df_clean))
print(df_clean.head(33))
# Out:
# Rows: 33
#                    borough  childcare_per_100
# 0     Barking and Dagenham          19.470513
# 1                   Barnet          30.810900
# 2                   Bexley          33.632047
# 3                    Brent          22.924162
# 4                  Bromley          43.369901
# 5                   Camden          33.078317
# 6           City of London         160.000000
# 7                  Croydon          28.797055
# 8                   Ealing          25.723872
# 9                  Enfield          24.764069
# 10               Greenwich          32.105490
# 11                 Hackney          33.784699
# 12  Hammersmith and Fulham          32.889466
# 13                Haringey          29.467986
# 14                  Harrow          30.340405
# 15                Havering          29.673305
# 16              Hillingdon          24.915922
# 17                Hounslow          25.968523
# 18               Islington          35.265790
# 19  Kensington and Chelsea          32.134660
# 20    Kingston upon Thames          38.350858
# 21                 Lambeth          39.636314
# 22                Lewisham          36.811626
# 23                  Merton          33.778289
# 24                  Newham          20.115844
# 25               Redbridge          27.504757
# 26    Richmond upon Thames          49.047849
# 27               Southwark          32.486954
# 28                  Sutton          31.184420
# 29           Tower Hamlets          22.101625
# 30          Waltham Forest          28.165812
# 31              Wandsworth          37.184551
# 32             Westminster          33.307927

# %%
#save merged dataset
df_clean.to_csv('../data_clean/childcare_access.csv', index=False)
