# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Part 1: Load data and basic overview

# %%
#import libraries
import pandas as pd

#load dataset
df = pd.read_csv('../data_clean/master_dataset.csv')

# %%
#basic preview
df.head()
# Out:
#      la_code                 borough   gld    fsm        sen     idaci  \
# 0  E09000007                  Camden  68.3  46.67  17.681992  0.182241
# 1  E09000012                 Hackney  69.5  44.66  19.183618  0.255382
# 2  E09000013  Hammersmith and Fulham  66.9  34.50  17.610787  0.181938
# 3  E09000014                Haringey  73.2  31.09  17.629577  0.201324
# 4  E09000019               Islington  66.6  49.69  22.219987  0.268195
#
#      ofsted  inspection_coverage  total_places  under5  childcare_per_100  \
# 0  3.148813             0.652372          5037    9934          50.704651
# 1  3.137548             0.666707          8233   16247          50.673971
# 2  3.173140             0.657718          4619    9237          50.005413
# 3  3.006351             0.773509          5700   14962          38.096511
# 4  3.208246             0.731183          5208   10798          48.231154
#
#    ethnic_diversity  average_house_price
# 0          0.812638               863493
# 1          0.828401               618385
# 2          0.793292               790884
# 3          0.825132               635522
# 4          0.790226               700374

# %%
#basic preview
df.describe()
# Out:
#              gld        fsm        sen      idaci     ofsted  \
# count  32.000000  32.000000  32.000000  32.000000  32.000000
# mean   69.043750  30.926875  16.822260   0.171634   3.082694
# std     2.750125   9.624605   2.350995   0.049960   0.089636
# min    64.800000  15.060000  12.526500   0.069148   2.923024
# 25%    66.850000  23.922500  14.970762   0.127727   3.020799
# 50%    68.900000  31.145000  16.916867   0.166412   3.075374
# 75%    70.500000  36.915000  18.453752   0.202775   3.126178
# max    75.600000  49.690000  22.219987   0.268195   3.334286
#
#        inspection_coverage  total_places        under5  childcare_per_100  \
# count            32.000000     32.000000     32.000000          32.000000
# mean              0.710271   7032.562500  16413.875000          44.400045
# std               0.048132   2081.592906   4934.281572          10.969801
# min               0.620612   3058.000000   6535.000000          25.071397
# 25%               0.681898   5566.000000  12754.500000          36.417267
# 50%               0.700816   6812.500000  16941.500000          44.922677
# 75%               0.748955   8260.000000  19244.500000          50.172552
# max               0.802342  11766.000000  25263.000000          78.782020
#
#        ethnic_diversity  average_house_price
# count         32.000000         3.200000e+01
# mean           0.779143         5.954519e+05
# std            0.097986         2.005741e+05
# min            0.545234         3.590350e+05
# 25%            0.784939         4.735872e+05
# 50%            0.811058         5.479955e+05
# 75%            0.835808         6.226692e+05
# max            0.891383         1.359067e+06

# %% [markdown]
# #### VISUALISATION

# %%
#import libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
#define variables
variables = ['fsm', 'sen', 'idaci', 'ofsted', 'total_places', 'under5', 'childcare_per_100', 'ethnic_diversity']

# %%
#create side-by-side visualisations
for var in variables:

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))

    x = df[var]
    y = df["gld"]

    # Scatter plot
    axes[0].scatter(x, y, alpha=0.8)

    # Regression line
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    axes[0].plot(x, p(x), linewidth=2)

    axes[0].set_xlabel(var)
    axes[0].set_ylabel("Good Level of Development (%)")
    axes[0].set_title(f"Relationship between {var} and GLD")

    # Bar chart
    df_sorted = df.sort_values(by=var)

    axes[1].barh(df_sorted["borough"], df_sorted[var])

    axes[1].set_title(f"{var} across London boroughs")
    axes[1].set_xlabel(var)

    plt.tight_layout()

    # Save the figure
    plt.savefig(
        f"../outputs/{var}_visualisation.png",
        dpi=300,
        bbox_inches="tight"
    )

    # Display the figure
    plt.show()
