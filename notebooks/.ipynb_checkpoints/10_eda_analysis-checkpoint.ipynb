# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Part 1: Load data and basic overview

# %%
#import libraries
import pandas as pd

#load dataset
df = pd.read_csv('../data_clean/master_dataset.csv')

# %%
#basic preview
df.head()
# Out:
#      la_code                 borough   gld    fsm        sen     idaci  \
# 0  E09000007                  Camden  68.3  46.67  17.681992  0.182241
# 1  E09000001          City of London  84.2  21.93  11.488783  0.054000
# 2  E09000012                 Hackney  69.5  44.66  19.183618  0.255382
# 3  E09000013  Hammersmith and Fulham  66.9  34.50  17.610787  0.181938
# 4  E09000014                Haringey  73.2  31.09  17.629577  0.201324
#
#      ofsted  total_places  under5  childcare_per_100  ethnic_diversity
# 0  1.851187          3286    9934          33.078317          0.953160
# 1  1.866279           344     215         160.000000          0.937560
# 2  1.862452          5489   16247          33.784699          0.957100
# 3  1.826860          3038    9237          32.889466          0.948323
# 4  1.993649          4409   14962          29.467986          0.956283

# %%
#basic preview
df.describe()
# Out:
#              gld        fsm        sen      idaci     ofsted  total_places  \
# count  33.000000  33.000000  33.000000  33.000000  33.000000     33.000000
# mean   69.503030  30.654242  16.660639   0.168070   1.915760   4823.878788
# std     3.779921   9.601618   2.493281   0.053267   0.088671   1575.044558
# min    64.800000  15.060000  11.488783   0.054000   1.665714    344.000000
# 25%    66.900000  22.760000  14.862947   0.125641   1.866279   3808.000000
# 50%    69.100000  31.090000  16.623858   0.163697   1.916741   5001.000000
# 75%    70.500000  36.360000  18.333231   0.201324   1.978600   5597.000000
# max    84.200000  49.690000  22.219987   0.268195   2.076976   8144.000000
#
#              under5  childcare_per_100  ethnic_diversity
# count     33.000000          33.000000         33.000000
# mean   15923.000000          35.114967          0.944567
# std     5615.862306          23.301486          0.024143
# min      215.000000          19.470513          0.886308
# 25%    11913.000000          27.504757          0.945257
# 50%    16621.000000          32.105490          0.952454
# 75%    18913.000000          33.784699          0.958713
# max    25263.000000         160.000000          0.972846

# %%
#confirm 
df[df['childcare_per_100']>100]
# Out:
#      la_code         borough   gld    fsm        sen  idaci    ofsted  \
# 1  E09000001  City of London  84.2  21.93  11.488783  0.054  1.866279
#
#    total_places  under5  childcare_per_100  ethnic_diversity
# 1           344     215              160.0           0.93756

# %%
#outlier for city of London
df['city_of_london_flag'] = (
    df['borough'] == 'City of London'
).astype(int)

# %% [markdown]
# ## Part 2: Correlation Matrix

# %%
##import needed libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#plot correlation matrix
corr = df.corr(numeric_only=True)

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#correlation 
corr
# Out:
#                           gld       fsm       sen     idaci    ofsted  \
# gld                  1.000000 -0.393048 -0.312377 -0.529444 -0.040118
# fsm                 -0.393048  1.000000  0.671496  0.794158 -0.095519
# sen                 -0.312377  0.671496  1.000000  0.653275 -0.049308
# idaci               -0.529444  0.794158  0.653275  1.000000  0.246212
# ofsted              -0.040118 -0.095519 -0.049308  0.246212  1.000000
# total_places        -0.116857 -0.134446  0.230417  0.136918  0.293136
# under5              -0.330064 -0.029123  0.020149  0.304036  0.500395
# childcare_per_100    0.769746 -0.201673 -0.288539 -0.457000 -0.198855
# ethnic_diversity    -0.247621  0.485094  0.224085  0.458120  0.210025
# city_of_london_flag  0.697995 -0.163114 -0.372376 -0.384435 -0.100175
#
#                      total_places    under5  childcare_per_100  \
# gld                     -0.116857 -0.330064           0.769746
# fsm                     -0.134446 -0.029123          -0.201673
# sen                      0.230417  0.020149          -0.288539
# idaci                    0.136918  0.304036          -0.457000
# ofsted                   0.293136  0.500395          -0.198855
# total_places             1.000000  0.792323          -0.445052
# under5                   0.792323  1.000000          -0.604825
# childcare_per_100       -0.445052 -0.604825           1.000000
# ethnic_diversity        -0.087134  0.290856          -0.213733
# city_of_london_flag     -0.510600 -0.502125           0.962130
#
#                      ethnic_diversity  city_of_london_flag
# gld                         -0.247621             0.697995
# fsm                          0.485094            -0.163114
# sen                          0.224085            -0.372376
# idaci                        0.458120            -0.384435
# ofsted                       0.210025            -0.100175
# total_places                -0.087134            -0.510600
# under5                       0.290856            -0.502125
# childcare_per_100           -0.213733             0.962130
# ethnic_diversity             1.000000            -0.052101
# city_of_london_flag         -0.052101             1.000000

# %%
#check outlier impact
df_no_city = df[df['borough'] != 'City of London']

corr_no_city = df_no_city.corr(numeric_only=True)

corr_no_city
# Out:
#                           gld       fsm       sen     idaci    ofsted  \
# gld                  1.000000 -0.395175 -0.078935 -0.394981  0.041829
# fsm                 -0.395175  1.000000  0.667018  0.803097 -0.113950
# sen                 -0.078935  0.667018  1.000000  0.595406 -0.093794
# idaci               -0.394981  0.803097  0.595406  1.000000  0.226128
# ofsted               0.041829 -0.113950 -0.093794  0.226128  1.000000
# total_places         0.389040 -0.256667  0.050479 -0.074803  0.282862
# under5               0.032968 -0.130127 -0.207862  0.139041  0.523094
# childcare_per_100    0.502988 -0.166342  0.275648 -0.346218 -0.377823
# ethnic_diversity    -0.295407  0.483722  0.220845  0.475205  0.206121
# city_of_london_flag       NaN       NaN       NaN       NaN       NaN
#
#                      total_places    under5  childcare_per_100  \
# gld                      0.389040  0.032968           0.502988
# fsm                     -0.256667 -0.130127          -0.166342
# sen                      0.050479 -0.207862           0.275648
# idaci                   -0.074803  0.139041          -0.346218
# ofsted                   0.282862  0.523094          -0.377823
# total_places             1.000000  0.720767           0.197165
# under5                   0.720767  1.000000          -0.516323
# childcare_per_100        0.197165 -0.516323           1.000000
# ethnic_diversity        -0.132459  0.306495          -0.601003
# city_of_london_flag           NaN       NaN                NaN
#
#                      ethnic_diversity  city_of_london_flag
# gld                         -0.295407                  NaN
# fsm                          0.483722                  NaN
# sen                          0.220845                  NaN
# idaci                        0.475205                  NaN
# ofsted                       0.206121                  NaN
# total_places                -0.132459                  NaN
# under5                       0.306495                  NaN
# childcare_per_100           -0.601003                  NaN
# ethnic_diversity             1.000000                  NaN
# city_of_london_flag               NaN                  NaN

# %% [markdown]
# #### VISUALISATION

# %%
#import libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
#define variables
variables = ['fsm', 'sen', 'idaci', 'ofsted', 'total_places', 'under5', 'childcare_per_100', 'ethnic_diversity']

# %%
#create side by side visualisations
for var in variables:
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    x = df[var]
    y = df['gld']
    axes[0].scatter(x, y)
    col = df[df['borough'] == 'City of London']
    axes[0].scatter(col[var], col['gld'])
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    axes[0].plot(x, p(x))
    axes[0].set_xlabel(var)
    axes[0].set_ylabel('GLD')
    axes[0].set_title(f'GLD vs {var}')
    
    df_sorted = df.sort_values(by=var)
    axes[1].barh(df_sorted['borough'], df_sorted[var])
    axes[1].set_title(f'{var} across boroughs')
    axes[1].set_xlabel(var)
    
    plt.tight_layout()
    plt.show()
