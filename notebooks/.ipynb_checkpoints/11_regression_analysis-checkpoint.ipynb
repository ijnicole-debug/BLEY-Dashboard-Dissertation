# %% [markdown]
# ## Regression Analysis

# %%
#load needed libraries
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd

# %%
#load master dataset
df = pd.read_csv('../data_clean/master_dataset.csv')

# %%
#display first five rows 
df.head()
# Out:
#      la_code                 borough   gld    fsm        sen     idaci  \
# 0  E09000007                  Camden  68.3  46.67  17.681992  0.182241
# 1  E09000001          City of London  84.2  21.93  11.488783  0.054000
# 2  E09000012                 Hackney  69.5  44.66  19.183618  0.255382
# 3  E09000013  Hammersmith and Fulham  66.9  34.50  17.610787  0.181938
# 4  E09000014                Haringey  73.2  31.09  17.629577  0.201324
#
#      ofsted  total_places  under5  childcare_per_100  ethnic_diversity
# 0  1.851187          3286    9934          33.078317          0.953160
# 1  1.866279           344     215         160.000000          0.937560
# 2  1.862452          5489   16247          33.784699          0.957100
# 3  1.826860          3038    9237          32.889466          0.948323
# 4  1.993649          4409   14962          29.467986          0.956283

# %%
#check dataset dimensions
df.shape
# Out:
# (33, 11)

# %% [markdown]
# ## Observation
# The final master dataset is imported for regression analysis. The dataset contains all 33 boroughs in Greater London and includes all selected variables used in this study.

# %%
#define vaiables
##dependent variable
y = df ['gld']

# %%
#independent variables
X =  df[['fsm', 'sen', 'idaci', 'ofsted', 'childcare_per_100', 'ethnic_diversity']]

# %%
#add constant for interception
X = sm.add_constant (X)

# %%
#run MLR and display result
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gld   R-squared:                       0.672
# Model:                            OLS   Adj. R-squared:                  0.597
# Method:                 Least Squares   F-statistic:                     8.897
# Date:                Mon, 15 Jun 2026   Prob (F-statistic):           2.54e-05
# Time:                        18:26:29   Log-Likelihood:                -71.781
# No. Observations:                  33   AIC:                             157.6
# Df Residuals:                      26   BIC:                             168.0
# Df Model:                           6
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                51.4215     20.873      2.464      0.021       8.517      94.326
# fsm                  -0.0842      0.097     -0.870      0.392      -0.283       0.115
# sen                   0.2326      0.246      0.946      0.353      -0.273       0.738
# idaci               -12.3602     17.949     -0.689      0.497     -49.256      24.535
# ofsted                5.4340      5.932      0.916      0.368      -6.760      17.628
# childcare_per_100     0.1173      0.022      5.403      0.000       0.073       0.162
# ethnic_diversity      4.5936     21.487      0.214      0.832     -39.574      48.761
# ==============================================================================
# Omnibus:                        2.586   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.275   Jarque-Bera (JB):                2.034
# Skew:                           0.606   Prob(JB):                        0.362
# Kurtosis:                       2.893   Cond. No.                     3.60e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## #Bivariate OLS (Simple regression)

# %%
#select variables
variables = ['fsm', 'sen', 'idaci', 'ofsted', 'childcare_per_100', 'ethnic_diversity']

# variables where HIGH = BAD (colour logic flips)
negative_vars = ['fsm', 'idaci', 'sen']

#store regression results
results = []

# %%
#loop through variables

for var in variables:

    # Create figure with two panels
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # Define x and y variables
    x = df[var]
    y = df['gld']

    # =============================================
    # LEFT PANEL
    # Scatter Plot + Regression Line
    # =============================================

    # Scatter plot for all boroughs
    axes[0].scatter(x, y)

    # Highlight City of London
    city = df[df['borough'] == 'City of London']

    axes[0].scatter(
        city[var],
        city['gld'],
        color='red',
        s=120,
        label='City of London'
    )

    # Fit regression line
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)

    axes[0].plot(x, p(x))

    # Fit Simple OLS Regression
    X_reg = sm.add_constant(df[[var]])

    model = sm.OLS(y, X_reg).fit()

    # Extract regression statistics
    coef = round(model.params[var], 3)
    pval = round(model.pvalues[var], 3)
    r2 = round(model.rsquared, 3)

    # Save regression results
    results.append({

        'Variable': var,
        'Coefficient': coef,
        'P_value': pval,
        'R_squared': r2

    })

    # Plot labels
    axes[0].set_xlabel(var.replace('_', ' ').title())
    axes[0].set_ylabel('Good Level of Development (GLD)')

    axes[0].set_title(

        f'{var.replace("_"," ").title()} vs GLD\n'
        f'Coefficient = {coef} | p = {pval} | R² = {r2}'

    )

    axes[0].legend()

    # =============================================
    # RIGHT PANEL
    # Borough Ranking
    # =============================================

    df_sorted = df.sort_values(by=var)

    # Define tertiles
    low_threshold = df_sorted[var].quantile(0.33)
    high_threshold = df_sorted[var].quantile(0.66)

    colours = []

    for value in df_sorted[var]:

        if var in negative_vars:

            # Lower values are more favourable

            if value <= low_threshold:
                colours.append('green')

            elif value >= high_threshold:
                colours.append('red')

            else:
                colours.append('orange')

        else:

            # Higher values are more favourable

            if value <= low_threshold:
                colours.append('red')

            elif value >= high_threshold:
                colours.append('green')

            else:
                colours.append('orange')

    # Horizontal bar chart

    axes[1].barh(

        df_sorted['borough'],
        df_sorted[var],
        color=colours

    )

    axes[1].set_xlabel(var.replace('_', ' ').title())

    axes[1].set_title(

        f'{var.replace("_"," ").title()} across London Boroughs\n'
        '(Green = favourable | Amber = moderate | Red = less favourable)'

    )

    plt.tight_layout()

    plt.show()

# ---------------------------------------------
# REGRESSION SUMMARY TABLE
# ---------------------------------------------

results_df = pd.DataFrame(results)

results_df
# Out:
#             Variable  Coefficient  P_value  R_squared
# 0                fsm       -0.155    0.024      0.154
# 1                sen       -0.474    0.077      0.098
# 2              idaci      -37.571    0.002      0.280
# 3             ofsted       -1.710    0.825      0.002
# 4  childcare_per_100        0.125    0.000      0.593
# 5   ethnic_diversity      -38.768    0.165      0.061
