# %% [markdown]
# ## Regression Analysis

# %%
#load needed libraries
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd

# %%
#load master dataset
df = pd.read_csv('../data_clean/master_dataset.csv')

# %%
#display first five rows 
df.head()
# Out:
#      la_code                 borough   gld    fsm        sen     idaci  \
# 0  E09000007                  Camden  68.3  46.67  17.681992  0.182241
# 1  E09000012                 Hackney  69.5  44.66  19.183618  0.255382
# 2  E09000013  Hammersmith and Fulham  66.9  34.50  17.610787  0.181938
# 3  E09000014                Haringey  73.2  31.09  17.629577  0.201324
# 4  E09000019               Islington  66.6  49.69  22.219987  0.268195
#
#      ofsted  total_places  under5  childcare_per_100  ethnic_diversity  \
# 0  1.207663          5037    9934          50.704651          0.812638
# 1  1.241710          8233   16247          50.673971          0.828401
# 2  1.201559          4619    9237          50.005413          0.793292
# 3  1.542105          5700   14962          38.096511          0.825132
# 4  1.310100          5208   10798          48.231154          0.790226
#
#    average_house_price
# 0               863493
# 1               618385
# 2               790884
# 3               635522
# 4               700374

# %%
#check dataset dimensions
df.shape
# Out:
# (32, 12)

# %%
#define vaiables
##dependent variable
y = df ['gld']

# %%
#independent variables
X =  df[['fsm', 'sen', 'idaci', 'ofsted', 'childcare_per_100', 'ethnic_diversity']]

# %%
#add constant for interception
X = sm.add_constant (X)

# %%
#run MLR and display result
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gld   R-squared:                       0.482
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     3.875
# Date:                Tue, 30 Jun 2026   Prob (F-statistic):            0.00717
# Time:                        09:19:02   Log-Likelihood:                -66.751
# No. Observations:                  32   AIC:                             147.5
# Df Residuals:                      25   BIC:                             157.8
# Df Model:                           6
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                42.7510      9.198      4.648      0.000      23.806      61.696
# fsm                  -0.0503      0.087     -0.576      0.570      -0.230       0.130
# sen                  -0.0779      0.290     -0.269      0.790      -0.675       0.519
# idaci                -5.6736     16.094     -0.353      0.727     -38.819      27.472
# ofsted               12.1836      4.729      2.576      0.016       2.445      21.923
# childcare_per_100     0.2200      0.071      3.101      0.005       0.074       0.366
# ethnic_diversity      4.8278      6.417      0.752      0.459      -8.389      18.045
# ==============================================================================
# Omnibus:                        0.197   Durbin-Watson:                   2.392
# Prob(Omnibus):                  0.906   Jarque-Bera (JB):                0.208
# Skew:                           0.157   Prob(JB):                        0.901
# Kurtosis:                       2.762   Cond. No.                     2.39e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## #Bivariate OLS (Simple regression)

# %%
#select variables
variables = ['fsm', 'sen', 'idaci', 'ofsted', 'childcare_per_100', 'ethnic_diversity']

# variables where HIGH = BAD (colour logic flips)
negative_vars = ['fsm', 'idaci', 'sen']

#store regression results
results = []

# %%
# Individual Variable Analysis- Scatter Plots, Simple OLS Regression and Borough Rankings
# Store regression results
results = []
# Loop through variables
for var in variables:

#Create figure with two panels
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

#Define x and y variables
    x = df[var]
    y = df["gld"]

#LEFT PANEL
# Scatter Plot + Regression Line
#Scatter plot
    axes[0].scatter(x, y)

#Fit regression line
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)

    axes[0].plot(x, p(x), linewidth=2)

#Simple OLS Regression
    X_reg = sm.add_constant(df[[var]])

    model = sm.OLS(y, X_reg).fit()

#Extract regression statistics
    coef = round(model.params[var], 3)
    pval = round(model.pvalues[var], 3)
    r2 = round(model.rsquared, 3)

#Store regression results
    results.append({

        "Variable": var,
        "Coefficient": coef,
        "P_value": pval,
        "R_squared": r2

    })

# Labels
    axes[0].set_xlabel(var.replace("_", " ").title())
    axes[0].set_ylabel("Good Level of Development (GLD)")

    axes[0].set_title(
        f"{var.replace('_',' ').title()} vs GLD\n"
        f"Coefficient = {coef} | p = {pval} | R² = {r2}"
    )
# RIGHT PANEL
# Borough Ranking
    df_sorted = df.sort_values(by=var)

#Define tertiles
    low_threshold = df_sorted[var].quantile(0.33)
    high_threshold = df_sorted[var].quantile(0.66)

    colours = []

    for value in df_sorted[var]:

        if var in negative_vars:

            # Lower values are more favourable

            if value <= low_threshold:
                colours.append("green")

            elif value >= high_threshold:
                colours.append("red")

            else:
                colours.append("orange")

        else:

            # Higher values are more favourable

            if value <= low_threshold:
                colours.append("red")

            elif value >= high_threshold:
                colours.append("green")

            else:
                colours.append("orange")

#Horizontal bar chart
    axes[1].barh(
        df_sorted["borough"],
        df_sorted[var],
        color=colours
    )

    axes[1].set_xlabel(var.replace("_", " ").title())

    axes[1].set_title(
        f"{var.replace('_',' ').title()} across London Boroughs\n"
        "(Green = favourable | Amber = moderate | Red = less favourable)"
    )

    plt.tight_layout()

    plt.show()

# %%
# REGRESSION SUMMARY TABLE
results_df = pd.DataFrame(results)
results_df
# Out:
#             Variable  Coefficient  P_value  R_squared
# 0                fsm       -0.113    0.025      0.156
# 1                sen       -0.092    0.668      0.006
# 2              idaci      -21.742    0.025      0.156
# 3             ofsted        1.034    0.800      0.002
# 4  childcare_per_100        0.112    0.011      0.199
# 5   ethnic_diversity       -8.291    0.101      0.087
