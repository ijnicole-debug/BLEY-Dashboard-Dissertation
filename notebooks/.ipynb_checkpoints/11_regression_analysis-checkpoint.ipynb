# %% [markdown]
# ## Regression Analysis

# %%
#load needed libraries
import pandas as pd
import statsmodels.api as sm

# %%
#load dataset
df = pd.read_csv('../data_clean/master_dataset.csv')

# %%
#define vaiables
##dependent variable
y = df ['gld']

# %%
#independent variables
X =  df[['fsm', 'sen', 'idaci', 'ofsted', 'childcare_per_100', 'ethnic_diversity']]

# %%
#add constant for interception
X = sm.add_constant (X)

# %%
#run regression
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gld   R-squared:                       0.672
# Model:                            OLS   Adj. R-squared:                  0.597
# Method:                 Least Squares   F-statistic:                     8.897
# Date:                Mon, 25 May 2026   Prob (F-statistic):           2.54e-05
# Time:                        18:47:11   Log-Likelihood:                -71.781
# No. Observations:                  33   AIC:                             157.6
# Df Residuals:                      26   BIC:                             168.0
# Df Model:                           6
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                51.4215     20.873      2.464      0.021       8.517      94.326
# fsm                  -0.0842      0.097     -0.870      0.392      -0.283       0.115
# sen                   0.2326      0.246      0.946      0.353      -0.273       0.738
# idaci               -12.3602     17.949     -0.689      0.497     -49.256      24.535
# ofsted                5.4340      5.932      0.916      0.368      -6.760      17.628
# childcare_per_100     0.1173      0.022      5.403      0.000       0.073       0.162
# ethnic_diversity      4.5936     21.487      0.214      0.832     -39.574      48.761
# ==============================================================================
# Omnibus:                        2.586   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.275   Jarque-Bera (JB):                2.034
# Skew:                           0.606   Prob(JB):                        0.362
# Kurtosis:                       2.893   Cond. No.                     3.60e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.api as sm

variables = [
    'fsm',
    'sen',
    'idaci',
    'ofsted',
    'childcare_per_100',
    'ethnic_diversity'
]

results = {}

for var in variables:
    
    X = sm.add_constant(df[[var]])
    y = df['gld']
    
    model = sm.OLS(y, X).fit()
    
    results[var] = {
        'coef': model.params[var],
        'p_value': model.pvalues[var],
        'r_squared': model.rsquared
    }

# view results
results
# Out:
# {'fsm': {'coef': -0.1547334650156777,
#   'p_value': 0.023650018329680705,
#   'r_squared': 0.15448699569686253},
#  'sen': {'coef': -0.47357746502336284,
#   'p_value': 0.07674874991183553,
#   'r_squared': 0.09757960713205038},
#  'idaci': {'coef': -37.57059700993402,
#   'p_value': 0.0015331021452864916,
#   'r_squared': 0.2803110789327775},
#  'ofsted': {'coef': -1.7101977859252102,
#   'p_value': 0.8245740700729414,
#   'r_squared': 0.0016094906862634817},
#  'childcare_per_100': {'coef': 0.12486675293404567,
#   'p_value': 1.6390095122689412e-07,
#   'r_squared': 0.5925096327257005},
#  'ethnic_diversity': {'coef': -38.76784294683924,
#   'p_value': 0.16471940834713822,
#   'r_squared': 0.06131603773247696}}

# %%
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

for var in variables:
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    x = df[var]
    y = df['gld']
    
    # -------------------------------
    # LEFT: SCATTER + TREND
    # -------------------------------
    axes[0].scatter(x, y)
    
    # highlight City of London
    col = df[df['borough'] == 'City of London']
    axes[0].scatter(col[var], col['gld'], color='red')
    
    # regression line
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    axes[0].plot(x, p(x))
    
    axes[0].set_xlabel(var)
    axes[0].set_ylabel('GLD')
    
    # -------------------------------
    # SIMPLE REGRESSION OUTPUT
    # -------------------------------
    X = sm.add_constant(df[[var]])
    model = sm.OLS(y, X).fit()
    
    coef = round(model.params[var], 3)
    pval = round(model.pvalues[var], 3)
    r2 = round(model.rsquared, 3)
    
    axes[0].set_title(
        f'{var} vs GLD\nCoef: {coef} | p: {pval} | R²: {r2}'
    )
    
    # -------------------------------
    # RIGHT: BAR CHART
    # -------------------------------
    df_sorted = df.sort_values(by=var)
    
    axes[1].barh(df_sorted['borough'], df_sorted[var])
    axes[1].set_title(f'{var} across boroughs')
    
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

for var in variables:
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    x = df[var]
    y = df['gld']
    
    # -------------------------------
    # LEFT: SCATTER + TREND
    # -------------------------------
    axes[0].scatter(x, y)
    
    # highlight City of London
    col = df[df['borough'] == 'City of London']
    axes[0].scatter(col[var], col['gld'], color='red')
    
    # regression line
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    axes[0].plot(x, p(x))
    
    axes[0].set_xlabel(var)
    axes[0].set_ylabel('GLD')
    
    # -------------------------------
    # SIMPLE REGRESSION OUTPUT
    # -------------------------------
    X = sm.add_constant(df[[var]])
    model = sm.OLS(y, X).fit()
    
    coef = round(model.params[var], 3)
    pval = round(model.pvalues[var], 3)
    r2 = round(model.rsquared, 3)
    
    axes[0].set_title(
        f'{var} vs GLD\nCoef: {coef} | p: {pval} | R²: {r2}'
    )
    
    # -------------------------------
    # RIGHT: BAR CHART
    # -------------------------------
    df_sorted = df.sort_values(by=var)
    
    axes[1].barh(df_sorted['borough'], df_sorted[var])
    axes[1].set_title(f'{var} across boroughs')
    
    plt.tight_layout()
    plt.show()
